# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
# import my implementation of the toolkit
import toolkit as tk
# import my implementation of the models
import models

# %% [markdown]
# ## Loading Data and preprocessing

# %%
# Abalone
abalone_names = ["sex", "length", "diameter", "height", "whole weight", "shucked weight", "viscera weight", "shell weight", "rings"]
abalone = tk.load_data("../classification_datasets/abalone.data", names=abalone_names)
abalone_columns = ['sex']
tk.one_hot_encoding(abalone, abalone_columns)

# Breast cancer wisconsin
breast_cancer_names = ['sample_code', 'clump_thickness', 'uniformity_of_cell_size', 'uniformity_of_cell_shape', 'marginal_adhesion', 'single_epithelial_cell_size', 'bare_nuclei', 'bland_chromatin', 'normal_nucleoli', 'motoses', 'class']
breast_cancer = tk.load_data("../classification_datasets/breast-cancer-wisconsin.data", names=breast_cancer_names, index_col=0)

# breast cancer: missing value denoted by ?
tk.handle_missing_values(breast_cancer)
breast_cancer_col = ['class']
tk.one_hot_encoding(breast_cancer, breast_cancer_col)

# Car
# arribute "class" is added for data loading purposes
car_names = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class'] 
car = tk.load_data("../classification_datasets/car.data", names=car_names)

# encoding ordinal
# treating doors and persons as ordinal categorical data as well
car_columns = {
    'buying': ['low', 'med', 'high', 'vhigh'],
    'maint': ['low', 'med', 'high', 'vhigh'],
    'doors': ['2', '3', '4', '5more'], 
    'persons': ['2', '4', 'more'],
    'lug_boot': ['small', 'med', 'big'],
    'safety': ['low', 'med', 'high'],
    'class': ['unacc', 'acc', 'good', 'vgood']
}
tk.encode_ordinal(car, car_columns)

# Forest Fires
# forestfires has header
forestfires = tk.load_data("../classification_datasets/forestfires.data", header=0)
# forest fires
ff_columns = {
    'month': ['jan','feb','mar','apr','may','jun','jul','aug','sep', 'oct', 'nov', 'dec'],
    'day': ['mon', 'tue', 'wed', 'thu', 'fri', 'sat', 'sun']
}
tk.encode_ordinal(forestfires, ff_columns)

# house votes
house__votes_names = ['class', 'handicapped', 'water_project_cost_sharing', 'adoption_of_the_budget_resolution', 'physician_fee_freeze', 'el_salvador_aid', 'religious_groups_in_schools', 'anti_satellite_test_ban', 'aid_to_nicaraguan_contras', 'mx_missile', 'immigration', 'synfuels_corporation_cutback', 'education_spending', 'superfund_right_to_sue', 'crime', 'duty_free_exports', 'export_administration_act_south_africa'] 
house_votes = tk.load_data("../classification_datasets/house-votes-84.data", names=house__votes_names)
house_votes_columns = house__votes_names
tk.one_hot_encoding(house_votes, house_votes_columns)

# Machine
machine_names = ['vendor', 'model', 'MYCT', 'MMIN', 'MMAX', 'CACH', 'CHMIN', 'CHMAX', 'PRP', 'ERP'] 
machine = tk.load_data("../classification_datasets/machine.data", names=machine_names)
# drop vendor and model
machine.drop(columns=['vendor', 'model'], inplace=True)

# %% [markdown]
# ### Data Split into Five Folds

# %%
k = 5
model = models.KNN(k=5)
hyperparam = [{'k': 1}, {'k': 5}]
car_target = car['class'].to_numpy()
car_data = car.drop(columns=['class']).to_numpy()
tk.k_2_cv(car_data, car_target, k, hyperparam, model, classification=True)
# Out:
# X_train size:  1382
# X_valid size:  346
# y_train size:  1382
# y_valid size:  346
# Round 0.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.8265895953757225, 0.9161849710982659]
# Round 0.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.8352601156069365, 0.9017341040462428]
# Round 1.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.8063583815028902, 0.8959537572254336]
# Round 1.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.7947976878612717, 0.8959537572254336]
# Round 2.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.8497109826589595, 0.9190751445086706]
# Round 2.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.861271676300578, 0.9277456647398844]
# Round 3.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.8352601156069365, 0.9046242774566474]
# Round 3.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.8265895953757225, 0.9075144508670521]
# Round 4.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.8121387283236994, 0.9046242774566474]
# Round 4.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.8208092485549133, 0.9017341040462428]
# The average performance is: [0.82687861 0.90751445]
# The best hyperparams setting is: [{'k': 5}]
# Round 0.1 performance testing of best hyperparameter setting.
# train size: 690. test size: 692
# Performance: 0.9046242774566474
# Round 0.2 performance testing of best hyperparameter setting.
# train size: 692. test size: 690
# Performance: 0.9014492753623189
# Round 1.1 performance testing of best hyperparameter setting.
# train size: 690. test size: 692
# Performance: 0.9017341040462428
# Round 1.2 performance testing of best hyperparameter setting.
# train size: 692. test size: 690
# Performance: 0.9043478260869565
# Round 2.1 performance testing of best hyperparameter setting.
# train size: 690. test size: 692
# Performance: 0.9190751445086706
# Round 2.2 performance testing of best hyperparameter setting.
# train size: 692. test size: 690
# Performance: 0.9159420289855073
# Round 3.1 performance testing of best hyperparameter setting.
# train size: 690. test size: 692
# Performance: 0.9089595375722543
# Round 3.2 performance testing of best hyperparameter setting.
# train size: 692. test size: 690
# Performance: 0.9217391304347826
# Round 4.1 performance testing of best hyperparameter setting.
# train size: 690. test size: 692
# Performance: 0.9190751445086706
# Round 4.2 performance testing of best hyperparameter setting.
# train size: 692. test size: 690
# Performance: 0.927536231884058
# The average performance is: 0.912448270084611
# ({'k': 5}, 0.912448270084611)

# %% [markdown]
# ### Calculation of Distance

# %%
forestfires.head()
# Out:
#    X  Y  month  day  FFMC   DMC     DC  ISI  temp  RH  wind  rain  area
# 0  7  5      2    4  86.2  26.2   94.3  5.1   8.2  51   6.7   0.0   0.0
# 1  7  4      9    1  90.6  35.4  669.1  6.7  18.0  33   0.9   0.0   0.0
# 2  7  4      9    5  90.6  43.7  686.9  6.7  14.6  33   1.3   0.0   0.0
# 3  8  6      2    4  91.7  33.3   77.5  9.0   8.3  97   4.0   0.2   0.0
# 4  8  6      2    6  89.3  51.3  102.2  9.6  11.4  99   1.8   0.0   0.0

# %%
# compare the first two points
x1 = [7,5,2,4,86.2,26.2,94.3,5.1,8.2,51,6.7,0.0]
x2 = [[7,4,9,1,90.6,35.4,669.1,6.7,18.0,33,0.9,0.0]]
# cyclic data month and day
cyclic = {
    2: 12,
    3: 7,
}
models.euclidean_distances(x1, x2, cyclic)
# Out:
# [575.3175470989913]

# %% [markdown]
# ### Calculation of Kernel Function

# %%
# assume x has nearest neighbors with xq
x = [7,5,2,4,86.2,26.2,94.3,5.1,8.2,51,6.7,0.0]
xq = [[7,4,9,1,90.6,35.4,669.1,6.7,18.0,33,0.9,0.0],
      [7,4,9,5,90.6,43.7,686.9,6.7,14.6,33,1.3,0.0],]
# same cyclic data 
cyclic = {
    2: 12,
    3: 7,
}
gamma = 0.1
models.gamma_kernel(x, xq, gamma, cyclic)
# Out:
# array([1.03341889e-25, 1.72292866e-26])

# %% [markdown]
# ### Example of a Point Classified Using k-nn

# %%
car.head()
# Out:
#    buying  maint  doors  persons  lug_boot  safety  class
# 0       3      3      0        0         0       0      0
# 1       3      3      0        0         0       1      0
# 2       3      3      0        0         0       2      0
# 3       3      3      0        0         1       0      0
# 4       3      3      0        0         1       1      0

# %%
knn_classifier = models.KNN(k=5)  # for classification
knn_classifier.fit(car_data, car_target)
X_test = [[3,3,0,1,0,0]]
neighbor, y_pred_classification = knn_classifier.predict(X_test)
print("neighbor_y: ", neighbor[0][0])
print("neighbor_x: ", neighbor[0][1])
print("prediction: ", y_pred_classification)
# Out:
# neighbor_y:  [0, 0, 0, 0, 0]
# neighbor_x:  [array([3, 3, 0, 1, 0, 0]), array([3, 3, 0, 0, 0, 0]), array([3, 3, 1, 1, 0, 0]), array([3, 3, 0, 2, 0, 0]), array([3, 3, 0, 1, 1, 0])]
# prediction:  [0]

# %% [markdown]
# ### Example of of a Point Regressed Using k-nn

# %%
abalone.head()
# Out:
#    length  diameter  height  whole weight  shucked weight  viscera weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    shell weight  rings  sex_M  sex_F  sex_I
# 0         0.150     15      1      0      0
# 1         0.070      7      1      0      0
# 2         0.210      9      0      1      0
# 3         0.155     10      1      0      0
# 4         0.055      7      0      0      1

# %%
abalone_target = abalone['rings'].to_numpy()
abalone_data = abalone.drop(columns=['rings']).to_numpy()

gamma = 1/abalone_target.std()
knn_regressor = models.KNN(k=5, gamma=gamma)  # for regression
knn_regressor.fit(abalone_data, abalone_target)
X_test = [[0.455,0.365,0.095,0.5140,0.2245,0.1010,0.150,1,0,0]]
neighbor, y_pred_regression = knn_regressor.predict(X_test)
print("neighbor_y: ", neighbor[0][0])
print("neighbor_x: ", neighbor[0][1])
print("prediction: ", y_pred_regression)
# Out:
# neighbor_y:  [15, 10, 8, 8, 8]
# neighbor_x:  [array([0.455 , 0.365 , 0.095 , 0.514 , 0.2245, 0.101 , 0.15  , 1.    ,
#        0.    , 0.    ]), array([0.46  , 0.35  , 0.12  , 0.515 , 0.224 , 0.108 , 0.1565, 1.    ,
#        0.    , 0.    ]), array([0.465 , 0.375 , 0.11  , 0.5   , 0.21  , 0.113 , 0.1505, 1.    ,
#        0.    , 0.    ]), array([0.48  , 0.37  , 0.1   , 0.5135, 0.243 , 0.1015, 0.135 , 1.    ,
#        0.    , 0.    ]), array([0.475 , 0.37  , 0.11  , 0.4895, 0.2185, 0.107 , 0.146 , 1.    ,
#        0.    , 0.    ])]
# prediction:  [9.811156501049624]

# %% [markdown]
# ### Example edited out of the training set using edited nearest neighbor

# %%
abalone.head()
# Out:
#    length  diameter  height  whole weight  shucked weight  viscera weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    shell weight  rings  sex_M  sex_F  sex_I
# 0         0.150     15      1      0      0
# 1         0.070      7      1      0      0
# 2         0.210      9      0      1      0
# 3         0.155     10      1      0      0
# 4         0.055      7      0      0      1

# %%
X_train, X_test, y_train, y_test = tk.train_test_split(data=abalone_data, target=abalone_target, split_percentage=0.8, classification=False)
gamma = 1/y_train.std()
knn_regressor = models.EditedKNN(k=5, epsilon=0.1, gamma=gamma)  # for regression
knn_regressor.fit(X_train, y_train, X_test, y_test)
# When we predicted using the first data, the prediction if out of range of epsilon
# so we are expecting it to be removed in the updated X_train after fit
X_test = X_train[0]
print("line 1 is now at: ", np.where(np.all(knn_regressor.X_train==X_test,axis=1)))
# Out:
# line 1 is now at:  (array([0]),)

# %%
X_test = X_train[2]
print("line 3 is now at: ", np.where(np.all(knn_regressor.X_train==X_test,axis=1)))
# Out:
# line 3 is now at:  (array([2]),)

# %% [markdown]
# ### Example added to the training set using condensed nearest neighbor

# %%
knn_regressor = models.CondensedKNN(k=3, epsilon=0.1, gamma=gamma)  # for regression
knn_regressor.fit(abalone_data, abalone_target)
# When we predicted using the first data, the prediction if out of range of epsilon
# so we are expecting add it to our condensed dataset
# X_test = [[0.455,0.365,0.095,0.5140,0.2245,0.1010,0.150,1,0,0]]
knn_regressor.X_train[0]
# Out:
# array([0.455 , 0.365 , 0.095 , 0.514 , 0.2245, 0.101 , 0.15  , 1.    ,
#        0.    , 0.    ])

# %% [markdown]
# # Experiments

# %% [markdown]
# ## KNN

# %% [markdown]
# Abalone

# %%
K=5 # 5-2 Cross Validation
abalone_target = abalone['rings'].to_numpy()
abalone_data = abalone.drop(columns=['rings']).to_numpy()
gamma = 1/abalone_target.std()
model = models.KNN(k=5, gamma=gamma)
hyperparam = []
k_knn = [1, 3, 5, 7, 9, 11, 13]
for k in k_knn:
    hyperparam.append({'k': k})
tk.k_2_cv(abalone_data, abalone_target, K, hyperparam, model, classification=False)
# Out:
# X_train size:  3341
# X_valid size:  836
# y_train size:  3341
# y_valid size:  836
# Round 0.1 of hyperparameter choosing.
# train size: 1670. test size: 836
# Performance of corresponding hyperparams: [2.014354066985646, 1.67191932883871, 1.6306339722457965, 1.6177363554617126, 1.6057045123284202, 1.596310583340928, 1.6003923264298778]
# Round 0.2 of hyperparameter choosing.
# train size: 1671. test size: 836
# Performance of corresponding hyperparams: [2.0574162679425836, 1.7118197482639033, 1.6468778401656787, 1.6241094316342495, 1.6086103888760528, 1.6032163212143433, 1.5941622911504203]
# Round 1.1 of hyperparameter choosing.
# train size: 1670. test size: 836
# Performance of corresponding hyperparams: [1.9712918660287082, 1.6793729803267812, 1.650797966071345, 1.6084897603243218, 1.6081368458050727, 1.5994779240177908, 1.5868768834304785]
# Round 1.2 of hyperparameter choosing.
# train size: 1671. test size: 836
# Performance of corresponding hyperparams: [1.9413875598086126, 1.7032538218319466, 1.6452087482593098, 1.6131614976807187, 1.5998033914469596, 1.5872851894105504, 1.5835523076636087]
# Round 2.1 of hyperparameter choosing.
# train size: 1670. test size: 836
# Performance of corresponding hyperparams: [2.041866028708134, 1.7340128237991521, 1.6440305574457494, 1.5924709719126737, 1.6037624681418388, 1.596276833285665, 1.5833579241574425]
# Round 2.2 of hyperparameter choosing.
# train size: 1671. test size: 836
# Performance of corresponding hyperparams: [1.9413875598086126, 1.6751423687022704, 1.6636602046319304, 1.6209870230095655, 1.613390339089047, 1.6153417649258477, 1.604235487677469]
# Round 3.1 of hyperparameter choosing.
# train size: 1670. test size: 836
# Performance of corresponding hyperparams: [1.9784688995215312, 1.7167441715304728, 1.6821920655470894, 1.62670038947041, 1.614187392780117, 1.6030529513254101, 1.5944256899174554]
# Round 3.2 of hyperparameter choosing.
# train size: 1671. test size: 836
# Performance of corresponding hyperparams: [2.069377990430622, 1.696647426099771, 1.6724457954442082, 1.6273854211682315, 1.615390614015664, 1.6063018761578784, 1.6188421080737558]
# Round 4.1 of hyperparameter choosing.
# train size: 1670. test size: 836
# Performance of corresponding hyperparams: [1.9318181818181819, 1.6964640992925055, 1.672614818791946, 1.6312625409888104, 1.6195315035834872, 1.6048370679437456, 1.594993171018122]
# Round 4.2 of hyperparameter choosing.
# train size: 1671. test size: 836
# Performance of corresponding hyperparams: [1.9784688995215312, 1.7142836845906066, 1.640229352138187, 1.6288128922592349, 1.610587672135305, 1.60460624159626, 1.5986638155274824]
# The average performance is: [1.99258373 1.69996605 1.65486913 1.61911163 1.60991051 1.60167068
#  1.5959502 ]
# The best hyperparams setting is: [{'k': 13}]
# Round 0.1 performance testing of best hyperparameter setting.
# train size: 1670. test size: 1671
# Performance: 1.5279088573425432
# Round 0.2 performance testing of best hyperparameter setting.
# train size: 1671. test size: 1670
# Performance: 1.5531968388733568
# Round 1.1 performance testing of best hyperparameter setting.
# train size: 1670. test size: 1671
# Performance: 1.540583567209261
# Round 1.2 performance testing of best hyperparameter setting.
# train size: 1671. test size: 1670
# Performance: 1.568373757513242
# Round 2.1 performance testing of best hyperparameter setting.
# train size: 1670. test size: 1671
# Performance: 1.529154629142346
# Round 2.2 performance testing of best hyperparameter setting.
# train size: 1671. test size: 1670
# Performance: 1.5657961021373676
# Round 3.1 performance testing of best hyperparameter setting.
# train size: 1670. test size: 1671
# Performance: 1.546487812560874
# Round 3.2 performance testing of best hyperparameter setting.
# train size: 1671. test size: 1670
# Performance: 1.5304518971703513
# Round 4.1 performance testing of best hyperparameter setting.
# train size: 1670. test size: 1671
# Performance: 1.5185907190129324
# Round 4.2 performance testing of best hyperparameter setting.
# train size: 1671. test size: 1670
# Performance: 1.5502220018765325
# The average performance is: 1.5430766182838807
# ({'k': 13}, 1.5430766182838807)

# %% [markdown]
# Breast Cancer

# %%
model = models.KNN(k=5)
hyperparam = []
k_knn = [1, 3, 5, 7, 9, 11, 13]
for k in k_knn:
    hyperparam.append({'k': k})
breast_cancer_label = breast_cancer['class_2'].to_numpy()
breast_cancer_data = breast_cancer.drop(columns=['class_2']).to_numpy()
tk.k_2_cv(breast_cancer_data, breast_cancer_label, K, hyperparam, model, classification=True)
# Out:
# X_train size:  558
# X_valid size:  141
# y_train size:  558
# y_valid size:  141
# Round 0.1 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.9574468085106383, 0.9645390070921985, 0.950354609929078, 0.9716312056737588, 0.9645390070921985, 0.9645390070921985, 0.9645390070921985]
# Round 0.2 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.9645390070921985, 0.9645390070921985, 0.9574468085106383, 0.9645390070921985, 0.9645390070921985, 0.9574468085106383, 0.9574468085106383]
# Round 1.1 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.9787234042553191, 0.950354609929078, 0.9716312056737588, 0.9574468085106383, 0.950354609929078, 0.9716312056737588, 0.9716312056737588]
# Round 1.2 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.9645390070921985, 0.9716312056737588, 0.9645390070921985, 0.9574468085106383, 0.9574468085106383, 0.9574468085106383, 0.9574468085106383]
# Round 2.1 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.9645390070921985, 0.9645390070921985, 0.9645390070921985, 0.9574468085106383, 0.9574468085106383, 0.9574468085106383, 0.9574468085106383]
# Round 2.2 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.950354609929078, 0.9645390070921985, 0.9645390070921985, 0.9574468085106383, 0.9574468085106383, 0.9645390070921985, 0.9645390070921985]
# Round 3.1 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.9645390070921985, 0.950354609929078, 0.9645390070921985, 0.9645390070921985, 0.9574468085106383, 0.9574468085106383, 0.9645390070921985]
# Round 3.2 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.9645390070921985, 0.9574468085106383, 0.9574468085106383, 0.9574468085106383, 0.9645390070921985, 0.9574468085106383, 0.9574468085106383]
# Round 4.1 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.9645390070921985, 0.9716312056737588, 0.950354609929078, 0.9574468085106383, 0.9645390070921985, 0.9574468085106383, 0.9574468085106383]
# Round 4.2 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.9574468085106383, 0.9574468085106383, 0.9645390070921985, 0.9645390070921985, 0.9716312056737588, 0.9716312056737588, 0.9574468085106383]
# The average performance is: [0.96312057 0.96170213 0.96099291 0.96099291 0.96099291 0.96170213
#  0.96099291]
# The best hyperparams setting is: [{'k': 1}]
# Round 0.1 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.9498207885304659
# Round 0.2 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.946236559139785
# Round 1.1 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.9605734767025089
# Round 1.2 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.953405017921147
# Round 2.1 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.946236559139785
# Round 2.2 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.946236559139785
# Round 3.1 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.946236559139785
# Round 3.2 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.953405017921147
# Round 4.1 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.9354838709677419
# Round 4.2 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.946236559139785
# The average performance is: 0.9483870967741936
# ({'k': 1}, 0.9483870967741936)

# %% [markdown]
# Car

# %%
model = models.KNN(k=5)
hyperparam = []
k_knn = [1, 3, 5, 7, 9, 11, 13]
for k in k_knn:
    hyperparam.append({'k': k})
car_target = car['class'].to_numpy()
car_data = car.drop(columns=['class']).to_numpy()
tk.k_2_cv(car_data, car_target, K, hyperparam, model, classification=True)
# Out:
# X_train size:  1382
# X_valid size:  346
# y_train size:  1382
# y_valid size:  346
# Round 0.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.8323699421965318, 0.8901734104046243, 0.9075144508670521, 0.9075144508670521, 0.9046242774566474, 0.9017341040462428, 0.8930635838150289]
# Round 0.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.8439306358381503, 0.8641618497109826, 0.9190751445086706, 0.9132947976878613, 0.9161849710982659, 0.9190751445086706, 0.9104046242774566]
# Round 1.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.838150289017341, 0.8959537572254336, 0.8988439306358381, 0.8959537572254336, 0.9046242774566474, 0.884393063583815, 0.8786127167630058]
# Round 1.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.8410404624277457, 0.8988439306358381, 0.9190751445086706, 0.9104046242774566, 0.9132947976878613, 0.9075144508670521, 0.9017341040462428]
# Round 2.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.8410404624277457, 0.9104046242774566, 0.9046242774566474, 0.9046242774566474, 0.9190751445086706, 0.9104046242774566, 0.9104046242774566]
# Round 2.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.8728323699421965, 0.9104046242774566, 0.9132947976878613, 0.9190751445086706, 0.9075144508670521, 0.9017341040462428, 0.8959537572254336]
# Round 3.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.8265895953757225, 0.884393063583815, 0.9017341040462428, 0.9161849710982659, 0.9046242774566474, 0.9017341040462428, 0.8930635838150289]
# Round 3.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.8352601156069365, 0.8959537572254336, 0.9075144508670521, 0.8930635838150289, 0.9046242774566474, 0.9161849710982659, 0.9046242774566474]
# Round 4.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.8265895953757225, 0.8959537572254336, 0.9075144508670521, 0.8901734104046243, 0.9132947976878613, 0.9017341040462428, 0.9132947976878613]
# Round 4.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.8323699421965318, 0.8901734104046243, 0.9017341040462428, 0.8988439306358381, 0.8959537572254336, 0.8901734104046243, 0.8872832369942196]
# The average performance is: [0.83901734 0.89364162 0.90809249 0.90491329 0.9083815  0.90346821
#  0.89884393]
# The best hyperparams setting is: [{'k': 9}]
# Round 0.1 performance testing of best hyperparameter setting.
# train size: 690. test size: 692
# Performance: 0.8988439306358381
# Round 0.2 performance testing of best hyperparameter setting.
# train size: 692. test size: 690
# Performance: 0.9231884057971015
# Round 1.1 performance testing of best hyperparameter setting.
# train size: 690. test size: 692
# Performance: 0.911849710982659
# Round 1.2 performance testing of best hyperparameter setting.
# train size: 692. test size: 690
# Performance: 0.9159420289855073
# Round 2.1 performance testing of best hyperparameter setting.
# train size: 690. test size: 692
# Performance: 0.9089595375722543
# Round 2.2 performance testing of best hyperparameter setting.
# train size: 692. test size: 690
# Performance: 0.9072463768115943
# Round 3.1 performance testing of best hyperparameter setting.
# train size: 690. test size: 692
# Performance: 0.8988439306358381
# Round 3.2 performance testing of best hyperparameter setting.
# train size: 692. test size: 690
# Performance: 0.9043478260869565
# Round 4.1 performance testing of best hyperparameter setting.
# train size: 690. test size: 692
# Performance: 0.9017341040462428
# Round 4.2 performance testing of best hyperparameter setting.
# train size: 692. test size: 690
# Performance: 0.908695652173913
# The average performance is: 0.9079651503727904
# ({'k': 9}, 0.9079651503727904)

# %% [markdown]
# Forest Fire

# %%
hyperparam = []
k_knn = [1, 3, 5, 7, 9, 11, 13]
for k in k_knn:
    hyperparam.append({'k': k})
forestfires_target = forestfires['area'].to_numpy()
forestfires_data = forestfires.drop(columns=['area']).to_numpy()
gamma = 1/forestfires_target.std()
cyclic = {
    2: 12,
    3: 7,
}
model = models.KNN(k=5, gamma=gamma, cyclic=cyclic)
tk.k_2_cv(forestfires_data, forestfires_target, K, hyperparam, model, classification=False)
# Out:
# X_train size:  413
# X_valid size:  104
# y_train size:  413
# y_valid size:  104
# Round 0.1 of hyperparameter choosing.
# train size: 206. test size: 104
# Performance of corresponding hyperparams: [22.613076923076925, 22.814670597867583, 22.299649238459203, 22.497474402114406, 23.5610932311678, 23.42269285099136, 23.230277216852862]
# Round 0.2 of hyperparameter choosing.
# train size: 207. test size: 104
# Performance of corresponding hyperparams: [25.20317307692308, 24.063490714558444, 26.197433337077253, 26.1275418489086, 26.707764413028393, 25.88712187404068, 25.987063839486602]
# Round 1.1 of hyperparameter choosing.
# train size: 206. test size: 104
# Performance of corresponding hyperparams: [24.32625, 26.22183706783411, 26.00750745323019, 25.46903420408527, 26.431071542457587, 26.237446485429324, 26.396454827240195]
# Round 1.2 of hyperparameter choosing.
# train size: 207. test size: 104
# Performance of corresponding hyperparams: [25.867596153846154, 22.611921583967096, 21.6894954151946, 21.749531026420193, 21.859386382316732, 22.418774346252466, 22.603993097088907]
# Round 2.1 of hyperparameter choosing.
# train size: 206. test size: 104
# Performance of corresponding hyperparams: [26.908173076923074, 24.980771740834548, 24.107112372914948, 22.97414610625081, 23.181819803997463, 22.912525009016314, 22.757396845927264]
# Round 2.2 of hyperparameter choosing.
# train size: 207. test size: 104
# Performance of corresponding hyperparams: [22.33932692307692, 21.76900285362005, 24.56539308205943, 25.48576797894307, 25.58739677880766, 26.433168089199384, 26.286964753009844]
# Round 3.1 of hyperparameter choosing.
# train size: 206. test size: 104
# Performance of corresponding hyperparams: [21.800769230769237, 21.67184548228194, 22.724568943308398, 22.04020085125874, 21.90455939736944, 21.588811774701238, 21.86131197964946]
# Round 3.2 of hyperparameter choosing.
# train size: 207. test size: 104
# Performance of corresponding hyperparams: [26.66826923076923, 28.932148754687923, 26.35387202473852, 26.881558866094448, 26.664066748434955, 25.931539471938752, 26.20689909206407]
# Round 4.1 of hyperparameter choosing.
# train size: 206. test size: 104
# Performance of corresponding hyperparams: [32.58778846153846, 30.397803109480517, 29.636519455091584, 27.684162509888097, 27.821850458308973, 27.26516968134757, 27.089092166949968]
# Round 4.2 of hyperparameter choosing.
# train size: 207. test size: 104
# Performance of corresponding hyperparams: [23.781346153846155, 22.496359348975624, 22.602703250368485, 22.162544122707303, 22.351369818116133, 22.04625727181556, 22.004649988196928]
# The average performance is: [25.20957692 24.59598513 24.61842546 24.30719619 24.60703786 24.41435069
#  24.44241038]
# The best hyperparams setting is: [{'k': 7}]
# Round 0.1 performance testing of best hyperparameter setting.
# train size: 206. test size: 207
# Performance: 25.393925337713974
# Round 0.2 performance testing of best hyperparameter setting.
# train size: 207. test size: 206
# Performance: 20.403339149657306
# Round 1.1 performance testing of best hyperparameter setting.
# train size: 206. test size: 207
# Performance: 18.514918239337984
# Round 1.2 performance testing of best hyperparameter setting.
# train size: 207. test size: 206
# Performance: 21.2734597492442
# Round 2.1 performance testing of best hyperparameter setting.
# train size: 206. test size: 207
# Performance: 16.888101508512104
# Round 2.2 performance testing of best hyperparameter setting.
# train size: 207. test size: 206
# Performance: 19.29835466852757
# Round 3.1 performance testing of best hyperparameter setting.
# train size: 206. test size: 207
# Performance: 19.194963637253203
# Round 3.2 performance testing of best hyperparameter setting.
# train size: 207. test size: 206
# Performance: 16.889769574087246
# Round 4.1 performance testing of best hyperparameter setting.
# train size: 206. test size: 207
# Performance: 20.12888311765185
# Round 4.2 performance testing of best hyperparameter setting.
# train size: 207. test size: 206
# Performance: 17.73889912118437
# The average performance is: 19.57246141031698
# ({'k': 7}, 19.57246141031698)

# %% [markdown]
# House Votes

# %%
model = models.KNN(k=5)
hyperparam = []
k_knn = [1, 3, 5, 7, 9, 11, 13]
for k in k_knn:
    hyperparam.append({'k': k})
house_votes_target = house_votes['class_republican'].to_numpy()
house_votes_data = house_votes.drop(columns=['class_republican']).to_numpy()
tk.k_2_cv(forestfires_data, forestfires_target, K, hyperparam, model, classification=True)
# Out:
# X_train size:  217
# X_valid size:  300
# y_train size:  217
# y_valid size:  300
# Round 0.1 of hyperparameter choosing.
# train size: 99. test size: 300
# Performance of corresponding hyperparams: [0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 0.2 of hyperparameter choosing.
# train size: 118. test size: 300
# Performance of corresponding hyperparams: [0.13, 0.15, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 1.1 of hyperparameter choosing.
# train size: 99. test size: 300
# Performance of corresponding hyperparams: [0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 1.2 of hyperparameter choosing.
# train size: 118. test size: 300
# Performance of corresponding hyperparams: [0.12666666666666668, 0.15666666666666668, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 2.1 of hyperparameter choosing.
# train size: 99. test size: 300
# Performance of corresponding hyperparams: [0.16, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 2.2 of hyperparameter choosing.
# train size: 118. test size: 300
# Performance of corresponding hyperparams: [0.13666666666666666, 0.15666666666666668, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 3.1 of hyperparameter choosing.
# train size: 99. test size: 300
# Performance of corresponding hyperparams: [0.16333333333333333, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 3.2 of hyperparameter choosing.
# train size: 118. test size: 300
# Performance of corresponding hyperparams: [0.13, 0.16, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 4.1 of hyperparameter choosing.
# train size: 99. test size: 300
# Performance of corresponding hyperparams: [0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 4.2 of hyperparameter choosing.
# train size: 118. test size: 300
# Performance of corresponding hyperparams: [0.14, 0.16, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# The average performance is: [0.14866667 0.16166667 0.16666667 0.16666667 0.16666667 0.16666667
#  0.16666667]
# The best hyperparams setting is: [{'k': 5}]
# Round 0.1 performance testing of best hyperparameter setting.
# train size: 99. test size: 118
# Performance: 0.8389830508474576
# Round 0.2 performance testing of best hyperparameter setting.
# train size: 118. test size: 99
# Performance: 0.98989898989899
# Round 1.1 performance testing of best hyperparameter setting.
# train size: 99. test size: 118
# Performance: 0.8389830508474576
# Round 1.2 performance testing of best hyperparameter setting.
# train size: 118. test size: 99
# Performance: 0.98989898989899
# Round 2.1 performance testing of best hyperparameter setting.
# train size: 99. test size: 118
# Performance: 0.8389830508474576
# Round 2.2 performance testing of best hyperparameter setting.
# train size: 118. test size: 99
# Performance: 0.98989898989899
# Round 3.1 performance testing of best hyperparameter setting.
# train size: 99. test size: 118
# Performance: 0.8389830508474576
# Round 3.2 performance testing of best hyperparameter setting.
# train size: 118. test size: 99
# Performance: 0.98989898989899
# Round 4.1 performance testing of best hyperparameter setting.
# train size: 99. test size: 118
# Performance: 0.8389830508474576
# Round 4.2 performance testing of best hyperparameter setting.
# train size: 118. test size: 99
# Performance: 0.98989898989899
# The average performance is: 0.9144410203732238
# ({'k': 5}, 0.9144410203732238)

# %% [markdown]
# Machine

# %%
hyperparam = []
k_knn = [1, 3, 5, 7, 9, 11, 13]
for k in k_knn:
    hyperparam.append({'k': k})
machine_target = machine['PRP'].to_numpy()
machine_data = machine.drop(columns=['PRP']).to_numpy()
gamma = 1/machine_target.std()
model = models.KNN(k=5, gamma=gamma)
tk.k_2_cv(machine_data, machine_target, K, hyperparam, model, classification=False)
# Out:
# X_train size:  167
# X_valid size:  42
# y_train size:  167
# y_valid size:  42
# Round 0.1 of hyperparameter choosing.
# train size: 83. test size: 42
# Performance of corresponding hyperparams: [48.333333333333336, 48.245045174774, 48.256949337350875, 49.490688352983376, 49.36784036699501, 49.36639081353333, 49.37067354532554]
# Round 0.2 of hyperparameter choosing.
# train size: 84. test size: 42
# Performance of corresponding hyperparams: [66.11904761904762, 69.00191966769896, 68.6563278708805, 68.81393862033953, 68.75219250534185, 68.76406927824048, 68.74851747363469]
# Round 1.1 of hyperparameter choosing.
# train size: 83. test size: 42
# Performance of corresponding hyperparams: [35.523809523809526, 32.80592194046643, 33.555603906266484, 33.453167498995505, 33.45677691831167, 33.50130191968285, 33.501071379273576]
# Round 1.2 of hyperparameter choosing.
# train size: 84. test size: 42
# Performance of corresponding hyperparams: [55.26190476190476, 53.749273133786446, 53.96178595171397, 54.61725293119922, 54.83172110439234, 54.86153931333776, 54.89822321178471]
# Round 2.1 of hyperparameter choosing.
# train size: 83. test size: 42
# Performance of corresponding hyperparams: [57.76190476190476, 53.837288548110976, 53.834052396111865, 54.02118537137523, 54.503334244552704, 54.49941692386011, 54.49336731616437]
# Round 2.2 of hyperparameter choosing.
# train size: 84. test size: 42
# Performance of corresponding hyperparams: [56.785714285714285, 59.47651539562141, 59.16594356766161, 60.9745857639236, 61.074593674923335, 61.112916776312716, 61.1193412537208]
# Round 3.1 of hyperparameter choosing.
# train size: 83. test size: 42
# Performance of corresponding hyperparams: [54.45238095238095, 50.23884113152526, 51.94162584966865, 51.81230720999635, 51.8685236982729, 51.81786995559481, 51.794747478761856]
# Round 3.2 of hyperparameter choosing.
# train size: 84. test size: 42
# Performance of corresponding hyperparams: [38.04761904761905, 37.20418293708964, 38.05662817381355, 37.929608823173695, 38.15907007147503, 38.133079624594465, 38.160621381822175]
# Round 4.1 of hyperparameter choosing.
# train size: 83. test size: 42
# Performance of corresponding hyperparams: [63.61904761904762, 62.04624324016155, 63.77012129441938, 63.710993383122954, 63.78497983486237, 63.682981097974455, 63.68488834479709]
# Round 4.2 of hyperparameter choosing.
# train size: 84. test size: 42
# Performance of corresponding hyperparams: [49.166666666666664, 49.64059181047536, 51.39692434611737, 51.97347876692141, 51.81151655698136, 51.79823272505445, 51.78542458772921]
# The average performance is: [52.50714286 51.6245823  52.25959627 52.67972067 52.7610549  52.75377984
#  52.7556876 ]
# The best hyperparams setting is: [{'k': 3}]
# Round 0.1 performance testing of best hyperparameter setting.
# train size: 83. test size: 84
# Performance: 38.52337446058643
# Round 0.2 performance testing of best hyperparameter setting.
# train size: 84. test size: 83
# Performance: 30.976392577487637
# Round 1.1 performance testing of best hyperparameter setting.
# train size: 83. test size: 84
# Performance: 33.693937953584566
# Round 1.2 performance testing of best hyperparameter setting.
# train size: 84. test size: 83
# Performance: 36.53398109421444
# Round 2.1 performance testing of best hyperparameter setting.
# train size: 83. test size: 84
# Performance: 23.314245224012165
# Round 2.2 performance testing of best hyperparameter setting.
# train size: 84. test size: 83
# Performance: 42.662850651676536
# Round 3.1 performance testing of best hyperparameter setting.
# train size: 83. test size: 84
# Performance: 30.358214387528104
# Round 3.2 performance testing of best hyperparameter setting.
# train size: 84. test size: 83
# Performance: 40.40255329723951
# Round 4.1 performance testing of best hyperparameter setting.
# train size: 83. test size: 84
# Performance: 34.170681594415846
# Round 4.2 performance testing of best hyperparameter setting.
# train size: 84. test size: 83
# Performance: 33.90471887230377
# The average performance is: 34.4540950113049
# ({'k': 3}, 34.4540950113049)

# %% [markdown]
# ## Condensed KNN

# %% [markdown]
# Abalone

# %%
K=5 # 5-2 Cross Validation
abalone_target = abalone['rings'].to_numpy()
abalone_data = abalone.drop(columns=['rings']).to_numpy()
gamma = 1/abalone_target.std()
model = models.CondensedKNN(gamma=gamma)
hyperparam = []
k_knn = [1, 3, 5, 7, 9, 11, 13]
epsilon = [0.001, 0.01, 0.1, 1]
for k in k_knn:
    for e in epsilon:
        hyperparam.append({'k': k, 'epsilon': e})
tk.k_2_cv(abalone_data, abalone_target, K, hyperparam, model, classification=False)
# Out:
# X_train size:  3341
# X_valid size:  836
# y_train size:  3341
# y_valid size:  836
# Round 0.1 of hyperparameter choosing.
# train size: 1670. test size: 836
# Performance of corresponding hyperparams: [1.9892344497607655, 1.9892344497607655, 1.9892344497607655, 2.076555023923445, 1.721529475130351, 1.721529475130351, 1.721529475130351, 1.7619507511812362, 1.6064752372787032, 1.6064752372787032, 1.6064752372787032, 1.7002138539034009, 1.5918211276907774, 1.5918211276907774, 1.5918211276907774, 1.690947704938403, 1.567285424763225, 1.567285424763225, 1.567285424763225, 1.6761229152940207, 1.5652929115318535, 1.5652929115318535, 1.5652929115318535, 1.6918190470173533, 1.590180392526352, 1.590180392526352, 1.590180392526352, 1.724172841849701]
# Round 0.2 of hyperparameter choosing.
# train size: 1671. test size: 836
# Performance of corresponding hyperparams:
hyperparam = []
k_knn = [1, 3, 5, 7, 9, 11, 13]
#epsilon = [0.01, 0.1, 0.5, 1, 1.5]
for k in k_knn:
    #for e in epsilon:
    hyperparam.append({'k': k})
breast_cancer_label = breast_cancer['class_2'].to_numpy()
breast_cancer_data = breast_cancer.drop(columns=['class_2']).to_numpy()        
tk.k_2_cv(breast_cancer_data, breast_cancer_label, K, hyperparam, model, classification=True)
# Out:
# X_train size:  558
# X_valid size:  141
# y_train size:  558
# y_valid size:  141
# Round 0.1 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.7446808510638298, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462]
# Round 0.2 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.6879432624113475, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462]
# Round 1.1 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.6737588652482269, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462]
# Round 1.2 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.6737588652482269, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462]
# Round 2.1 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.7943262411347518, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462]
# Round 2.2 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.6666666666666666, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462]
# Round 3.1 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.6950354609929078, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462]
# Round 3.2 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.7588652482269503, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462]
# Round 4.1 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.7588652482269503, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462]
# Round 4.2 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.7446808510638298, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462, 0.6524822695035462]
# The average performance is: [0.71985816 0.65248227 0.65248227 0.65248227 0.65248227 0.65248227
#  0.65248227]
# The best hyperparams setting is: [{'k': 1}]
# Round 0.1 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.7491039426523297
# Round 0.2 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.7670250896057348
# Round 1.1 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.6630824372759857
# Round 1.2 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.7526881720430108
# Round 2.1 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.8924731182795699
# Round 2.2 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.7419354838709677
# Round 3.1 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.7670250896057348
# Round 3.2 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.7706093189964157
# Round 4.1 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.7132616487455197
# Round 4.2 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.7670250896057348
# The average performance is: 0.7584229390681003
# ({'k': 1}, 0.7584229390681003)

# %% [markdown]
# Car

# %%
K=5 # 5-2 Cross Validation
model = models.CondensedKNN()
hyperparam = []
k_knn = [1, 3, 5, 7, 9, 11, 13]
# epsilon = [0.01, 0.1, 0.5, 1, 1.5]
for k in k_knn:
    #for e in epsilon:
    hyperparam.append({'k': k})
        
car_target = car['class'].to_numpy()
car_data = car.drop(columns=['class']).to_numpy()
tk.k_2_cv(car_data, car_target, K, hyperparam, model, classification=True)
# Out:
# X_train size:  1382
# X_valid size:  346
# y_train size:  1382
# y_valid size:  346
# Round 0.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.18497109826589594, 0.12716763005780346, 0.10404624277456648, 0.1069364161849711, 0.11271676300578035, 0.09826589595375723, 0.10115606936416185]
# Round 0.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.3208092485549133, 0.19653179190751446, 0.21098265895953758, 0.18208092485549132, 0.1907514450867052, 0.18208092485549132, 0.1676300578034682]
# Round 1.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.2514450867052023, 0.15606936416184972, 0.11271676300578035, 0.10982658959537572, 0.08670520231213873, 0.07514450867052024, 0.057803468208092484]
# Round 1.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.30057803468208094, 0.21098265895953758, 0.18497109826589594, 0.13583815028901733, 0.11560693641618497, 0.1069364161849711, 0.11271676300578035]
# Round 2.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.1791907514450867, 0.11560693641618497, 0.07803468208092486, 0.07225433526011561, 0.07225433526011561, 0.06069364161849711, 0.05491329479768786]
# Round 2.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.10982658959537572, 0.07514450867052024, 0.06358381502890173, 0.04335260115606936, 0.03757225433526012, 0.03757225433526012, 0.03757225433526012]
# Round 3.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.16184971098265896, 0.13583815028901733, 0.11849710982658959, 0.0953757225433526, 0.08670520231213873, 0.03757225433526012, 0.03757225433526012]
# Round 3.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.23121387283236994, 0.14739884393063585, 0.11271676300578035, 0.1069364161849711, 0.09826589595375723, 0.10982658959537572, 0.09826589595375723]
# Round 4.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.3208092485549133, 0.13583815028901733, 0.0953757225433526, 0.06647398843930635, 0.06358381502890173, 0.04046242774566474, 0.03757225433526012]
# Round 4.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.2658959537572254, 0.20809248554913296, 0.1329479768786127, 0.11271676300578035, 0.0953757225433526, 0.06358381502890173, 0.06358381502890173]
# The average performance is: [0.23265896 0.15086705 0.12138728 0.10317919 0.09595376 0.08121387
#  0.07687861]
# The best hyperparams setting is: [{'k': 1}]
# Round 0.1 performance testing of best hyperparameter setting.
# train size: 690. test size: 692
# Performance: 0.13439306358381503
# Round 0.2 performance testing of best hyperparameter setting.
# train size: 692. test size: 690
# Performance: 0.21739130434782608
# Round 1.1 performance testing of best hyperparameter setting.
# train size: 690. test size: 692
# Performance: 0.19797687861271676
# Round 1.2 performance testing of best hyperparameter setting.
# train size: 692. test size: 690
# Performance: 0.2956521739130435
# Round 2.1 performance testing of best hyperparameter setting.
# train size: 690. test size: 692
# Performance: 0.19219653179190752
# Round 2.2 performance testing of best hyperparameter setting.
# train size: 692. test size: 690
# Performance: 0.18695652173913044
# Round 3.1 performance testing of best hyperparameter setting.
# train size: 690. test size: 692
# Performance: 0.21242774566473988
# Round 3.2 performance testing of best hyperparameter setting.
# train size: 692. test size: 690
# Performance: 0.2579710144927536
# Round 4.1 performance testing of best hyperparameter setting.
# train size: 690. test size: 692
# Performance: 0.21676300578034682
# Round 4.2 performance testing of best hyperparameter setting.
# train size: 692. test size: 690
# Performance: 0.21304347826086956
# The average performance is: 0.21247717181871492
# ({'k': 1}, 0.21247717181871492)

# %% [markdown]
# Forest Fire

# %%
K=5 # 5-2 Cross Validation
forestfires_target = forestfires['area'].to_numpy()
forestfires_data = forestfires.drop(columns=['area']).to_numpy()
gamma = 1/forestfires_target.std()
cyclic = {
    2: 12,
    3: 7,
}
hyperparam = []
k_knn = [1, 3, 5, 7, 9, 11, 13]
epsilon = [0.001, 0.05, 0.01, 0.1, 0.5]
for k in k_knn:
    for e in epsilon:
        hyperparam.append({'k': k, 'epsilon': e})
model = models.CondensedKNN(gamma=gamma, cyclic=cyclic)
tk.k_2_cv(forestfires_data, forestfires_target, K, hyperparam, model, classification=False)
# Out:
# X_train size:  413
# X_valid size:  104
# y_train size:  413
# y_valid size:  104
# Round 0.1 of hyperparameter choosing.
# train size: 206. test size: 104
# Performance of corresponding hyperparams: [9.63701923076923, 9.63701923076923, 9.63701923076923, 9.63701923076923, 9.63451923076923, 10.893284086054056, 10.937444308324569, 10.912511891880605, 10.937444308324569, 11.824427005646516, 16.146876025100497, 16.20933801896995, 16.161775379775044, 16.217900250895134, 16.339765762978658, 15.50917935059752, 15.556874177657562, 15.502907025790702, 15.556023311363408, 15.582490626474204, 14.651875096131247, 14.680901421183023, 14.655802454822627, 14.685522020470962, 14.783653370123956, 14.91194188461433, 14.920168020808463, 14.908731729108954, 14.917857660859172, 15.104719250064958, 14.565481475039102, 14.603939280370705, 14.560156847467074, 14.62944091563593, 14.734063277508186]
# Round 0.2 of hyperparameter choosing.
# train size: 207. test size: 104
# Performance of corresponding hyperparams: [29.164326923076924, 29.164326923076924, 29.164326923076924, 29.164326923076924, 29.151442307692307, 18.74299203256467, 18.74299203256467, 18.74299203256467, 18.74145385171805, 18.91999757506498, 20.365865709545712, 20.365865709545712, 20.365865709545712, 20.364955735502157, 22.113675423821615, 19.02440676805979, 19.02440676805979, 19.02440676805979, 19.005316934653475, 20.44971214341935, 20.23333299012512, 20.23333299012512, 20.23333299012512, 20.231008927317014, 20.556753297251365, 21.142342541489956, 21.142342541489956, 21.142342541489956, 21.14358503638023, 21.53037643521984, 22.68275269406592, 22.68275269406592, 22.68275269406592, 22.68142844038983, 22.98784884477312]
# Round 1.1 of hyperparameter choosing.
# train size: 206. test size: 104
# Performance of corresponding hyperparams: [21.708173076923075, 21.708173076923075, 21.708173076923075, 21.708173076923075, 21.70423076923077, 15.172494362997357, 15.172494362997357, 15.172494362997357, 15.175221482983087, 15.062320619612736, 16.39102551096544, 16.43140033232094, 16.43140033232094, 16.4608590117412, 16.602207918165217, 14.830955656748339, 14.803328155089433, 14.803328155089433, 14.802634362098944, 15.069727797679025, 14.047582424213694, 14.046273147012032, 14.046273147012032, 14.073452401328563, 16.479763793469395, 15.134316076723227, 15.139115959624549, 15.139115959624549, 15.17466577896464, 19.520182108323958, 19.22250657552938, 19.24076992323718, 19.24076992323718, 19.264178347991205, 19.735442722119657]
# Round 1.2 of hyperparameter choosing.
# train size: 207. test size: 104
# Performance of corresponding hyperparams:
1 of hyperparameter choosing.
# train size: 206. test size: 104
# Performance of corresponding hyperparams: [14.268557692307692, 14.268557692307692, 14.268557692307692, 14.268557692307692, 14.24923076923077, 12.789903258012023, 12.789903258012023, 12.789903258012023, 12.789903258012023, 12.83402711754534, 12.611182321837521, 12.611182321837521, 12.611182321837521, 12.611182321837521, 12.825479187269506, 12.740471677587264, 12.740471677587264, 12.740471677587264, 12.740471677587264, 13.336918751733007, 13.450416735166865, 13.450416735166865, 13.450416735166865, 13.450416735166865, 13.663454995600633, 13.155330638935721, 13.155330638935721, 13.155330638935721, 13.155330638935721, 13.430367766158515, 12.764424715830675, 12.764424715830675, 12.764424715830675, 12.764424715830675, 13.1412140864894]
# Round 4.2 of hyperparameter choosing.
# train size: 207. test size: 104
# Performance of corresponding hyperparams: [20.213173076923077, 20.213173076923077, 20.213173076923077, 20.213173076923077, 20.24259615384615, 17.627087935666676, 17.627087935666676, 17.627087935666676, 17.627087935666676, 17.65399418909737, 19.468787640685147, 19.468787640685147, 19.468787640685147, 19.468787640685147, 21.918033402752773, 20.98418056503376, 20.98418056503376, 20.98418056503376, 20.98418056503376, 22.292097714711687, 21.986431083946773, 21.986431083946773, 21.986431083946773, 21.986431083946773, 21.376995870968315, 20.689555677267812, 20.689555677267812, 20.689555677267812, 20.689555677267812, 21.01304252662666, 21.822670124189226, 21.822670124189226, 21.822670124189226, 21.822670124189226, 23.34988437431422]
# The average performance is: [19.83213462 19.83213462 19.83213462 19.83213462 19.95794231 18.23995422
#  18.23977226 18.241877   18.24023727 18.20701788 18.64897208 18.66611795
#  18.65766616 18.67242196 19.23974882 18.18563864 18.31175507 18.18048517
#  18.32446226 18.94498608 18.43532615 18.4659121  18.4337305  18.48013976
#  18.79693253 18.20709523 18.24778422 18.20719999 18.25905593 18.98758339
#  18.44943992 18.57752606 18.45084371 18.6025991  19.20912802]
# The best hyperparams setting is: [{'k': 7, 'epsilon': 0.01}]
# Round 0.1 performance testing of best hyperparameter setting.
# train size: 206. test size: 207
# Performance: 25.688519003542396
# Round 0.2 performance testing of best hyperparameter setting.
# train size: 207. test size: 206
# Performance: 23.854677247764652
# Round 1.1 performance testing of best hyperparameter setting.
# train size: 206. test size: 207
# Performance: 26.6179051162522
# Round 1.2 performance testing of best hyperparameter setting.
# train size: 207. test size: 206
# Performance: 21.769497861691324
# Round 2.1 performance testing of best hyperparameter setting.
# train size: 206. test size: 207
# Performance: 24.40005738673209
# Round 2.2 performance testing of best hyperparameter setting.
# train size: 207. test size: 206
# Performance: 25.13300037350818
# Round 3.1 performance testing of best hyperparameter setting.
# train size: 206. test size: 207
# Performance: 25.27618947241603
# Round 3.2 performance testing of best hyperparameter setting.
# train size: 207. test size: 206
# Performance: 22.728050473611983
# Round 4.1 performance testing of best hyperparameter setting.
# train size: 206. test size: 207
# Performance: 19.896382839059182
# Round 4.2 performance testing of best hyperparameter setting.
# train size: 207. test size: 206
# Performance: 26.249738255368868
# The average performance is: 24.161401802994693
# ({'k': 7, 'epsilon': 0.01}, 24.161401802994693)

# %% [markdown]
# House Vote

# %%
model = models.CondensedKNN()
hyperparam = []
k_knn = [1, 3, 5, 7, 9, 11, 13]
# epsilon = [0.01, 0.1, 0.5, 1, 1.5]
for k in k_knn:
    # for e in epsilon:
    hyperparam.append({'k': k})
house_votes_target = house_votes['class_republican'].to_numpy()
house_votes_data = house_votes.drop(columns=['class_republican']).to_numpy()
tk.k_2_cv(house_votes_data, house_votes_target, K, hyperparam, model, classification=True)
# Out:
# X_train size:  347
# X_valid size:  88
# y_train size:  347
# y_valid size:  88
# Round 0.1 of hyperparameter choosing.
# train size: 173. test size: 88
# Performance of corresponding hyperparams: [0.8977272727272727, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635]
# Round 0.2 of hyperparameter choosing.
# train size: 174. test size: 88
# Performance of corresponding hyperparams: [0.6931818181818182, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635]
# Round 1.1 of hyperparameter choosing.
# train size: 173. test size: 88
# Performance of corresponding hyperparams: [0.6931818181818182, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635]
# Round 1.2 of hyperparameter choosing.
# train size: 174. test size: 88
# Performance of corresponding hyperparams: [0.7727272727272727, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635]
# Round 2.1 of hyperparameter choosing.
# train size: 173. test size: 88
# Performance of corresponding hyperparams: [0.6931818181818182, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635]
# Round 2.2 of hyperparameter choosing.
# train size: 174. test size: 88
# Performance of corresponding hyperparams: [0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635]
# Round 3.1 of hyperparameter choosing.
# train size: 173. test size: 88
# Performance of corresponding hyperparams: [0.8295454545454546, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635]
# Round 3.2 of hyperparameter choosing.
# train size: 174. test size: 88
# Performance of corresponding hyperparams: [0.8863636363636364, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635]
# Round 4.1 of hyperparameter choosing.
# train size: 173. test size: 88
# Performance of corresponding hyperparams: [0.5909090909090909, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635]
# Round 4.2 of hyperparameter choosing.
# train size: 174. test size: 88
# Performance of corresponding hyperparams: [0.8295454545454546, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635, 0.38636363636363635]
# The average performance is: [0.72727273 0.38636364 0.38636364 0.38636364 0.38636364 0.38636364
#  0.38636364]
# The best hyperparams setting is: [{'k': 1}]
# Round 0.1 performance testing of best hyperparameter setting.
# train size: 173. test size: 174
# Performance: 0.6954022988505747
# Round 0.2 performance testing of best hyperparameter setting.
# train size: 174. test size: 173
# Performance: 0.7109826589595376
# Round 1.1 performance testing of best hyperparameter setting.
# train size: 173. test size: 174
# Performance: 0.8103448275862069
# Round 1.2 performance testing of best hyperparameter setting.
# train size: 174. test size: 173
# Performance: 0.838150289017341
# Round 2.1 performance testing of best hyperparameter setting.
# train size: 173. test size: 174
# Performance: 0.7011494252873564
# Round 2.2 performance testing of best hyperparameter setting.
# train size: 174. test size: 173
# Performance: 0.884393063583815
# Round 3.1 performance testing of best hyperparameter setting.
# train size: 173. test size: 174
# Performance: 0.4482758620689655
# Round 3.2 performance testing of best hyperparameter setting.
# train size: 174. test size: 173
# Performance: 0.8323699421965318
# Round 4.1 performance testing of best hyperparameter setting.
# train size: 173. test size: 174
# Performance: 0.7758620689655172
# Round 4.2 performance testing of best hyperparameter setting.
# train size: 174. test size: 173
# Performance: 0.8323699421965318
# The average performance is: 0.7529300378712378
# ({'k': 1}, 0.7529300378712378)

# %% [markdown]
# Machine

# %%
K=5 # 5-2 Cross Validation
hyperparam = []
k_knn = [1, 3, 5, 7, 9, 11, 13]
epsilon = [0.001, 0.01, 0.1, 1]
for k in k_knn:
    for e in epsilon:
        hyperparam.append({'k': k, 'epsilon': e})
machine_target = machine['PRP'].to_numpy()
machine_data = machine.drop(columns=['PRP']).to_numpy()
gamma = 1/machine_target.std()
model = models.CondensedKNN(gamma=gamma)
tk.k_2_cv(machine_data, machine_target, K, hyperparam, model, classification=False)
# Out:
# X_train size:  167
# X_valid size:  42
# y_train size:  167
# y_valid size:  42
# Round 0.1 of hyperparameter choosing.
# train size: 83. test size: 42
# Performance of corresponding hyperparams: [39.11904761904762, 39.11904761904762, 39.11904761904762, 37.57142857142857, 36.44019597543187, 36.44019597543187, 36.44019597543187, 36.44019597543187, 40.91216996596548, 40.91216996596548, 40.91216996596548, 40.91608739917359, 40.75219760193255, 40.75219760193255, 40.75219760193255, 40.75052444612079, 40.71366009661132, 40.71366009661132, 40.71366009661132, 40.71594189651256, 40.703425697324796, 40.703425697324796, 40.703425697324796, 40.68595959440594, 40.69554246044123, 40.69554246044123, 40.69554246044123, 40.69493946098972]
# Round 0.2 of hyperparameter choosing.
# train size: 84. test size: 42
# Performance of corresponding hyperparams: [31.333333333333332, 31.333333333333332, 31.333333333333332, 31.333333333333332, 31.69953192779438, 31.69953192779438, 31.69953192779438, 31.69953192779438, 31.52522322340732, 31.52522322340732, 31.52522322340732, 31.52522322340732, 31.14415737948047, 31.14415737948047, 31.14415737948047, 31.14528252379508, 31.5937978242621, 31.5937978242621, 31.5937978242621, 31.594458014797684, 31.56100085927487, 31.56100085927487, 31.56100085927487, 31.564644370699234, 31.51171016523077, 31.51171016523077, 31.51171016523077, 31.515074432553245]
# Round 1.1 of hyperparameter choosing.
# train size: 83. test size: 42
# Performance of corresponding hyperparams: [43.785714285714285, 43.785714285714285, 43.785714285714285, 43.785714285714285, 43.47130741604548, 43.47130741604548, 43.47130741604548, 43.47130741604548, 46.052920560097675, 46.052920560097675, 46.052920560097675, 46.052920560097675, 45.65458187821338, 45.65458187821338, 45.65458187821338, 45.65458187821338, 46.266623639047765, 46.266623639047765, 46.266623639047765, 46.266623639047765, 46.244611992857, 46.244611992857, 46.244611992857, 46.244611992857, 46.24559487522172, 46.24559487522172, 46.24559487522172, 46.2475078578285]
# Round 1.2 of hyperparameter choosing.
# train size: 84. test size: 42
# Performance of corresponding hyperparams:
2 of hyperparameter choosing.
# train size: 84. test size: 42
# Performance of corresponding hyperparams: [33.88095238095238, 33.88095238095238, 33.88095238095238, 33.88095238095238, 31.4516362879389, 31.4516362879389, 31.4516362879389, 31.4516362879389, 30.902139509580667, 30.902139509580667, 30.902139509580667, 30.902139509580667, 30.850751844536553, 30.850751844536553, 30.850751844536553, 30.850751844536553, 30.840874274539427, 30.840874274539427, 30.840874274539427, 30.840874274539427, 30.837913213082917, 30.837913213082917, 30.837913213082917, 30.837981506256362, 30.837528081099883, 30.837528081099883, 30.837528081099883, 30.83738194544908]
# The average performance is: [35.23333333 35.23333333 35.23333333 35.17619048 35.28269494 35.28269494
#  35.28269494 35.38827326 36.00346702 36.00346702 36.00346702 36.10308052
#  35.90359813 35.90359813 35.90359813 36.0027387  36.02428835 36.02428835
#  36.02428835 36.12382456 36.00472578 36.00472578 36.00472578 36.10267972
#  36.00119814 36.00119814 36.00119814 36.10094058]
# The best hyperparams setting is: [{'k': 1, 'epsilon': 1}]
# Round 0.1 performance testing of best hyperparameter setting.
# train size: 83. test size: 84
# Performance: 35.01190476190476
# Round 0.2 performance testing of best hyperparameter setting.
# train size: 84. test size: 83
# Performance: 44.91566265060241
# Round 1.1 performance testing of best hyperparameter setting.
# train size: 83. test size: 84
# Performance: 56.642857142857146
# Round 1.2 performance testing of best hyperparameter setting.
# train size: 84. test size: 83
# Performance: 34.373493975903614
# Round 2.1 performance testing of best hyperparameter setting.
# train size: 83. test size: 84
# Performance: 36.19047619047619
# Round 2.2 performance testing of best hyperparameter setting.
# train size: 84. test size: 83
# Performance: 50.373493975903614
# Round 3.1 performance testing of best hyperparameter setting.
# train size: 83. test size: 84
# Performance: 41.416666666666664
# Round 3.2 performance testing of best hyperparameter setting.
# train size: 84. test size: 83
# Performance: 42.19277108433735
# Round 4.1 performance testing of best hyperparameter setting.
# train size: 83. test size: 84
# Performance: 38.45238095238095
# Round 4.2 performance testing of best hyperparameter setting.
# train size: 84. test size: 83
# Performance: 54.506024096385545
# The average performance is: 43.40757314974182
# ({'k': 1, 'epsilon': 1}, 43.40757314974182)

# %% [markdown]
# ## Edited KNN

# %% [markdown]
# Need to reload model for edited

# %% [markdown]
# abalone

# %%
K=5 # 5-2 Cross Validation
abalone_target = abalone['rings'].to_numpy()
abalone_data = abalone.drop(columns=['rings']).to_numpy()
gamma = 1/abalone_target.std()
model = models.EditedKNN(gamma=gamma)
hyperparam = []
# for faster computation, using three k values at a time
k_knn = [9, 11, 13]
epsilon = [0.001, 0.01, 0.1, 1]
for k in k_knn:
    for e in epsilon:
        hyperparam.append({'k': k, 'epsilon': e})
tk.k_2_cv(abalone_data, abalone_target, K, hyperparam, model, classification=False)
# Out:
# X_train size:  3341
# X_valid size:  836
# y_train size:  3341
# y_valid size:  836
# Round 0.1 of hyperparameter choosing.
# train size: 1670. test size: 836
# Performance of corresponding hyperparams: [1.607660444790643, 1.607660444790643, 1.607660444790643, 1.607660444790643, 1.5942473816014782, 1.5942473816014782, 1.5942473816014782, 1.5915425711256437, 1.5953184693319422, 1.5953184693319422, 1.5953184693319422, 1.5953184693319422]
# Round 0.2 of hyperparameter choosing.
# train size: 1671. test size: 836
# Performance of corresponding hyperparams: [1.585814293571819, 1.585814293571819, 1.585814293571819, 1.5855490493388056, 1.5919610005454867, 1.5919610005454867, 1.5919610005454867, 1.5902281755307082, 1.5985170704778477, 1.5985170704778477, 1.5985170704778477, 1.5985170704778477]
# Round 1.1 of hyperparameter choosing.
# train size: 1670. test size: 836
# Performance of corresponding hyperparams: [1.6131009610667835, 1.6131009610667835, 1.6131009610667835, 1.6131009610667835, 1.5954551425294436, 1.5954551425294436, 1.5954551425294436, 1.595346374820185, 1.5996236566330257, 1.5996236566330257, 1.5996236566330257, 1.5996236566330257]
# Round 1.2 of hyperparameter choosing.
# train size: 1671. test size: 836
# Performance of corresponding hyperparams: [1.5882986424271341, 1.5882986424271341, 1.5882986424271341, 1.5911057779507929, 1.590068766094091, 1.590068766094091, 1.590068766094091, 1.590068766094091, 1.5967650974897134, 1.5967650974897134, 1.5967650974897134, 1.5996939807817798]
# Round 2.1 of hyperparameter choosing.
# train size: 1670. test size: 836
# Performance of corresponding hyperparams: [1.6183386763958734, 1.6183386763958734, 1.6183386763958734, 1.6183386763958734, 1.6233823122104916, 1.6233823122104916, 1.6233823122104916, 1.6233823122104916, 1.6302954736217126, 1.6302954736217126, 1.6302954736217126, 1.6302954736217126]
# Round 2.2 of hyperparameter choosing.
# train size: 1671. test size: 836
# Performance of corresponding hyperparams: [1.58949784329978, 1.58949784329978, 1.58949784329978, 1.590824839117738, 1.5783375263852122, 1.5783375263852122, 1.5783375263852122, 1.5787593195029408, 1.559308210501975, 1.559308210501975, 1.559308210501975, 1.5614252375264026]
# Round 3.1 of hyperparameter choosing.
# train size: 1670. test size: 836
# Performance of corresponding hyperparams: [1.6077597177292966, 1.6077597177292966, 1.6077597177292966, 1.6086853918976178, 1.5965408678752937, 1.5965408678752937, 1.5965408678752937, 1.59675593835367, 1.5898751590413696, 1.5898751590413696, 1.5898751590413696, 1.5884890895755248]
# Round 3.2 of hyperparameter choosing.
# train size: 1671. test size: 836
# Performance of corresponding hyperparams: [1.5890555873259442, 1.5890555873259442, 1.5890555873259442, 1.5890555873259442, 1.579154590277024, 1.579154590277024, 1.579154590277024, 1.579154590277024, 1.5723427609020315, 1.5723427609020315, 1.5723427609020315, 1.5723427609020315]
# Round 4.1 of hyperparameter choosing.
# train size: 1670. test size: 836
# Performance of corresponding hyperparams: [1.6081821244010939, 1.6081821244010939, 1.6081821244010939, 1.6081821244010939, 1.6025002598916094, 1.6025002598916094, 1.6025002598916094, 1.6025002598916094, 1.5925996414837056, 1.5925996414837056, 1.5925996414837056, 1.5925996414837056]
# Round 4.2 of hyperparameter choosing.
# train size: 1671. test size: 836
# Performance of corresponding hyperparams: [1.5873485482598464, 1.5873485482598464, 1.5873485482598464, 1.586824677439767, 1.5996667308565804, 1.5996667308565804, 1.5996667308565804, 1.5996667308565804, 1.6032943039984544, 1.6032943039984544, 1.6032943039984544, 1.602278814380817]
# The average performance is: [1.59950568 1.59950568 1.59950568 1.59993275 1.59513146 1.59513146
#  1.59513146 1.5947405  1.59379398 1.59379398 1.59379398 1.59405842]
# The best hyperparams setting is: [{'k': 13, 'epsilon': 0.001}]
# Round 0.1 performance testing of best hyperparameter setting.
# train size: 1670. test size: 1671
# Performance: 1.5101504304924966
# Round 0.2 performance testing of best hyperparameter setting.
# train size: 1671. test size: 1670
# Performance: 1.5574847272598018
# Round 1.1 performance testing of best hyperparameter setting.
# train size: 1670. test size: 1671
# Performance: 1.5473017672083262
# Round 1.2 performance testing of best hyperparameter setting.
# train size: 1671. test size: 1670
# Performance: 1.5571905204117398
# Round 2.1 performance testing of best hyperparameter setting.
# train size: 1670. test size: 1671
# Performance: 1.5675601363247158
# Round 2.2 performance testing of best hyperparameter setting.
# train size: 1671. test size: 1670
# Performance: 1.4891578749250867
# Round 3.1 performance testing of best hyperparameter setting.
# train size: 1670. test size: 1671
# Performance: 1.5560343049100738
# Round 3.2 performance testing of best hyperparameter setting.
# train size: 1671. test size: 1670
# Performance: 1.5175540831335883
# Round 4.1 performance testing of best hyperparameter setting.
# train size: 1670. test size: 1671
# Performance: 1.5780091089812576
# Round 4.2 performance testing of best hyperparameter setting.
# train size: 1671. test size: 1670
# Performance: 1.5283127329669823
# The average performance is: 1.540875568661407
# ({'k': 13, 'epsilon': 0.001}, 1.540875568661407)

# %% [markdown]
# Breast Cancer

# %%
K=5 # 5-2 Cross Validation
model = models.EditedKNN()
hyperparam = []
k_knn = [1, 3, 5, 7, 9, 11, 13]
for k in k_knn:
    hyperparam.append({'k': k})

breast_cancer_label = breast_cancer['class_2'].to_numpy()
breast_cancer_data = breast_cancer.drop(columns=['class_2']).to_numpy()
tk.k_2_cv(breast_cancer_data, breast_cancer_label, K, hyperparam, model, classification=True)
# Out:
# X_train size:  558
# X_valid size:  141
# y_train size:  558
# y_valid size:  141
# Round 0.1 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.9432624113475178, 0.9645390070921985, 0.9645390070921985, 0.950354609929078, 0.9574468085106383, 0.9574468085106383, 0.950354609929078]
# Round 0.2 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.950354609929078, 0.9645390070921985, 0.9645390070921985, 0.9574468085106383, 0.9574468085106383, 0.9645390070921985, 0.9574468085106383]
# Round 1.1 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.9716312056737588, 0.9645390070921985, 0.950354609929078, 0.9574468085106383, 0.9574468085106383, 0.9574468085106383, 0.9574468085106383]
# Round 1.2 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.950354609929078, 0.9645390070921985, 0.9645390070921985, 0.9645390070921985, 0.9645390070921985, 0.9645390070921985, 0.9645390070921985]
# Round 2.1 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.9716312056737588, 0.9716312056737588, 0.9574468085106383, 0.9574468085106383, 0.9574468085106383, 0.9574468085106383, 0.9574468085106383]
# Round 2.2 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.9432624113475178, 0.950354609929078, 0.9574468085106383, 0.9574468085106383, 0.9645390070921985, 0.950354609929078, 0.950354609929078]
# Round 3.1 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.9574468085106383, 0.9716312056737588, 0.9716312056737588, 0.9645390070921985, 0.9716312056737588, 0.9574468085106383, 0.9574468085106383]
# Round 3.2 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.9645390070921985, 0.9645390070921985, 0.9574468085106383, 0.950354609929078, 0.9574468085106383, 0.9645390070921985, 0.9574468085106383]
# Round 4.1 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.9432624113475178, 0.9574468085106383, 0.9574468085106383, 0.950354609929078, 0.9574468085106383, 0.9645390070921985, 0.9645390070921985]
# Round 4.2 of hyperparameter choosing.
# train size: 279. test size: 141
# Performance of corresponding hyperparams: [0.9574468085106383, 0.9574468085106383, 0.9574468085106383, 0.9574468085106383, 0.950354609929078, 0.950354609929078, 0.950354609929078]
# The average performance is: [0.95531915 0.96312057 0.96028369 0.95673759 0.95957447 0.95886525
#  0.95673759]
# The best hyperparams setting is: [{'k': 3}]
# Round 0.1 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.967741935483871
# Round 0.2 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.96415770609319
# Round 1.1 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.982078853046595
# Round 1.2 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.978494623655914
# Round 2.1 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.974910394265233
# Round 2.2 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.9498207885304659
# Round 3.1 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.974910394265233
# Round 3.2 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.974910394265233
# Round 4.1 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.967741935483871
# Round 4.2 performance testing of best hyperparameter setting.
# train size: 279. test size: 279
# Performance: 0.9713261648745519
# The average performance is: 0.9706093189964159
# ({'k': 3}, 0.9706093189964159)

# %% [markdown]
# Car

# %%
K=5 # 5-2 Cross Validation
model = models.EditedKNN()
hyperparam = []
k_knn = [ 1, 3, 5, 7, 9, 11, 13]
for k in k_knn:
    hyperparam.append({'k': k})
car_target = car['class'].to_numpy()
car_data = car.drop(columns=['class']).to_numpy()
tk.k_2_cv(car_data, car_target, K, hyperparam, model, classification=True)
# Out:
# X_train size:  1382
# X_valid size:  346
# y_train size:  1382
# y_valid size:  346
# Round 0.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.8497109826589595, 0.9132947976878613, 0.930635838150289, 0.9219653179190751, 0.9248554913294798, 0.9161849710982659, 0.9219653179190751]
# Round 0.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.8786127167630058, 0.9075144508670521, 0.9190751445086706, 0.9190751445086706, 0.9190751445086706, 0.8930635838150289, 0.8930635838150289]
# Round 1.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.8554913294797688, 0.9046242774566474, 0.9104046242774566, 0.9277456647398844, 0.9219653179190751, 0.9132947976878613, 0.9190751445086706]
# Round 1.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.8526011560693642, 0.9277456647398844, 0.9364161849710982, 0.9277456647398844, 0.9277456647398844, 0.930635838150289, 0.9248554913294798]
# Round 2.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.8583815028901735, 0.9161849710982659, 0.9219653179190751, 0.930635838150289, 0.9248554913294798, 0.9017341040462428, 0.9046242774566474]
# Round 2.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.8757225433526011, 0.9277456647398844, 0.930635838150289, 0.9393063583815029, 0.9393063583815029, 0.9450867052023122, 0.9335260115606936]
# Round 3.1 of hyperparameter choosing.
# train size: 690. test size: 346
# Performance of corresponding hyperparams: [0.861271676300578, 0.9248554913294798, 0.930635838150289, 0.9132947976878613, 0.9219653179190751, 0.9335260115606936, 0.9277456647398844]
# Round 3.2 of hyperparameter choosing.
# train size: 692. test size: 346
# Performance of corresponding hyperparams: [0.
2 of hyperparameter choosing.
# train size: 207. test size: 104
# Performance of corresponding hyperparams: [29.09423076923077, 29.09423076923077, 29.09423076923077, 29.09423076923077, 29.09423076923077, 32.30207607625686, 32.30207607625686, 32.30207607625686, 32.30207607625686, 32.30207607625686, 32.498016655015995, 32.498016655015995, 32.498016655015995, 32.498016655015995, 32.498016655015995, 29.90625630205179, 29.90625630205179, 29.90625630205179, 29.90625630205179, 29.90625630205179, 30.741572354542008, 30.741572354542008, 30.741572354542008, 30.741572354542008, 30.741572354542008, 30.532807176153543, 30.532807176153543, 30.532807176153543, 30.532807176153543, 30.532807176153543, 29.821960401155742, 29.821960401155742, 29.821960401155742, 29.821960401155742, 29.821960401155742]
# Round 4.1 of hyperparameter choosing.
# train size: 206. test size: 104
# Performance of corresponding hyperparams: [27.992884615384607, 27.992884615384607, 27.992884615384607, 27.992884615384607, 27.992884615384607, 31.622424915522622, 31.622424915522622, 31.622424915522622, 31.622424915522622, 31.622424915522622, 31.003073465324153, 31.003073465324153, 31.003073465324153, 31.003073465324153, 31.003073465324153, 31.307353544247288, 31.307353544247288, 31.307353544247288, 31.307353544247288, 31.307353544247288, 30.9970029693047, 30.9970029693047, 30.9970029693047, 30.9970029693047, 30.9970029693047, 30.697761014613477, 30.697761014613477, 30.697761014613477, 30.697761014613477, 30.697761014613477, 30.177296664145356, 30.177296664145356, 30.177296664145356, 30.177296664145356, 30.177296664145356]
# Round 4.2 of hyperparameter choosing.
# train size: 207. test size: 104
# Performance of corresponding hyperparams: [26.369519230769225, 26.369519230769225, 26.369519230769225, 26.369519230769225, 26.369519230769225, 26.33977873732135, 26.33977873732135, 26.33977873732135, 26.33977873732135, 26.33977873732135, 30.979452391416736, 30.979452391416736, 30.979452391416736, 30.979452391416736, 30.979452391416736, 30.295608392629788, 30.295608392629788, 30.295608392629788, 30.295608392629788, 30.295608392629788, 29.6012554535993, 29.6012554535993, 29.6012554535993, 29.6012554535993, 29.636170284096345, 29.02007315118808, 29.02007315118808, 29.02007315118808, 29.02007315118808, 29.02007315118808, 28.516164140274135, 28.516164140274135, 28.516164140274135, 28.516164140274135, 28.516164140274135]
# The average performance is: [30.99794231 30.99794231 30.99794231 30.99794231 30.99794231 31.97121385
#  31.97121385 31.97121385 31.97121385 31.97140655 31.56363749 31.56363749
#  31.56363749 31.56363749 31.56392422 30.65938065 30.65938065 30.65938065
#  30.65938065 30.66123482 30.40242389 30.40242389 30.40242389 30.40242389
#  30.40591538 30.00678456 30.00678456 30.00678456 30.00678456 30.00678456
#  29.52078056 29.52078056 29.52078056 29.52078056 29.52078056]
# The best hyperparams setting is: [{'k': 13, 'epsilon': 0.001}]
# Round 0.1 performance testing of best hyperparameter setting.
# train size: 206. test size: 207
# Performance: 14.833522700165
# Round 0.2 performance testing of best hyperparameter setting.
# train size: 207. test size: 206
# Performance: 15.611576390533026
# Round 1.1 performance testing of best hyperparameter setting.
# train size: 206. test size: 207
# Performance: 14.694909549244198
# Round 1.2 performance testing of best hyperparameter setting.
# train size: 207. test size: 206
# Performance: 15.746816483937645
# Round 2.1 performance testing of best hyperparameter setting.
# train size: 206. test size: 207
# Performance: 13.8949679081078
# Round 2.2 performance testing of best hyperparameter setting.
# train size: 207. test size: 206
# Performance: 15.580025167796483
# Round 3.1 performance testing of best hyperparameter setting.
# train size: 206. test size: 207
# Performance: 15.224474863216098
# Round 3.2 performance testing of best hyperparameter setting.
# train size: 207. test size: 206
# Performance: 15.779346758667861
# Round 4.1 performance testing of best hyperparameter setting.
# train size: 206. test size: 207
# Performance: 14.753117625643105
# Round 4.2 performance testing of best hyperparameter setting.
# train size: 207. test size: 206
# Performance: 14.380058748495685
# The average performance is: 15.049881619580692
# ({'k': 13, 'epsilon': 0.001}, 15.049881619580692)

# %% [markdown]
# House Vote

# %%
K=5 # 5-2 Cross Validation
model = models.EditedKNN()
hyperparam = []
k_knn = [1, 3, 5, 7, 9, 11, 13]
for k in k_knn:
    hyperparam.append({'k': k})
house_votes_target = house_votes['class_republican'].to_numpy()
house_votes_data = house_votes.drop(columns=['class_republican']).to_numpy()
tk.k_2_cv(forestfires_data, forestfires_target, K, hyperparam, model, classification=True)
# Out:
# X_train size:  217
# X_valid size:  300
# y_train size:  217
# y_valid size:  300
# Round 0.1 of hyperparameter choosing.
# train size: 99. test size: 300
# Performance of corresponding hyperparams: [0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 0.2 of hyperparameter choosing.
# train size: 118. test size: 300
# Performance of corresponding hyperparams: [0.13333333333333333, 0.16, 0.16333333333333333, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 1.1 of hyperparameter choosing.
# train size: 99. test size: 300
# Performance of corresponding hyperparams: [0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 1.2 of hyperparameter choosing.
# train size: 118. test size: 300
# Performance of corresponding hyperparams: [0.15333333333333332, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 2.1 of hyperparameter choosing.
# train size: 99. test size: 300
# Performance of corresponding hyperparams: [0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 2.2 of hyperparameter choosing.
# train size: 118. test size: 300
# Performance of corresponding hyperparams: [0.15666666666666668, 0.16333333333333333, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 3.1 of hyperparameter choosing.
# train size: 99. test size: 300
# Performance of corresponding hyperparams: [0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 3.2 of hyperparameter choosing.
# train size: 118. test size: 300
# Performance of corresponding hyperparams: [0.14333333333333334, 0.16333333333333333, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 4.1 of hyperparameter choosing.
# train size: 99. test size: 300
# Performance of corresponding hyperparams: [0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# Round 4.2 of hyperparameter choosing.
# train size: 118. test size: 300
# Performance of corresponding hyperparams: [0.15, 0.16, 0.16333333333333333, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]
# The average performance is: [0.157      0.16466667 0.166      0.16666667 0.16666667 0.16666667
#  0.16666667]
# The best hyperparams setting is: [{'k': 7}]
# Round 0.1 performance testing of best hyperparameter setting.
# train size: 99. test size: 118
# Performance: 0.8389830508474576
# Round 0.2 performance testing of best hyperparameter setting.
# train size: 118. test size: 99
# Performance: 0.98989898989899
# Round 1.1 performance testing of best hyperparameter setting.
# train size: 99. test size: 118
# Performance: 0.8389830508474576
# Round 1.2 performance testing of best hyperparameter setting.
# train size: 118. test size: 99
# Performance: 0.98989898989899
# Round 2.1 performance testing of best hyperparameter setting.
# train size: 99. test size: 118
# Performance: 0.8389830508474576
# Round 2.2 performance testing of best hyperparameter setting.
# train size: 118. test size: 99
# Performance: 0.98989898989899
# Round 3.1 performance testing of best hyperparameter setting.
# train size: 99. test size: 118
# Performance: 0.8389830508474576
# Round 3.2 performance testing of best hyperparameter setting.
# train size: 118. test size: 99
# Performance: 0.98989898989899
# Round 4.1 performance testing of best hyperparameter setting.
# train size: 99. test size: 118
# Performance: 0.8389830508474576
# Round 4.2 performance testing of best hyperparameter setting.
# train size: 118. test size: 99
# Performance: 0.98989898989899
# The average performance is: 0.9144410203732238
# ({'k': 7}, 0.9144410203732238)

# %% [markdown]
# Machine

# %%
K=5 # 5-2 Cross Validation
hyperparam = []
k_knn = [5, 7, 9, 11, 13]
epsilon = [0.001, 0.01, 0.1, 1]
for k in k_knn:
    for e in epsilon:
        hyperparam.append({'k': k, 'epsilon': e})
machine_target = machine['PRP'].to_numpy()
machine_data = machine.drop(columns=['PRP']).to_numpy()
gamma = 1/machine_target.std()
model = models.EditedKNN(gamma=gamma)
tk.k_2_cv(machine_data, machine_target, K, hyperparam, model, classification=False)
# Out:
# X_train size:  167
# X_valid size:  42
# y_train size:  167
# y_valid size:  42
# Round 0.1 of hyperparameter choosing.
# train size: 83. test size: 42
# Performance of corresponding hyperparams: [36.27482387050867, 36.27482387050867, 36.27482387050867, 36.27482387050867, 36.133019672671544, 36.133019672671544, 36.133019672671544, 36.133019672671544, 36.36804826659661, 36.36804826659661, 36.36804826659661, 36.36804826659661, 36.68498553853577, 36.68498553853577, 36.68498553853577, 36.68498553853577, 36.740177341216025, 36.740177341216025, 36.740177341216025, 36.740177341216025]
# Round 0.2 of hyperparameter choosing.
# train size: 84. test size: 42
# Performance of corresponding hyperparams: [32.41255089152351, 32.41255089152351, 32.41255089152351, 32.41255089152351, 32.76005989666362, 32.76005989666362, 32.76005989666362, 32.76005989666362, 32.77064325341407, 32.77064325341407, 32.77064325341407, 32.77064325341407, 32.72316310224113, 32.72316310224113, 32.72316310224113, 32.72316310224113, 32.71276476337507, 32.71276476337507, 32.71276476337507, 32.71276476337507]
# Round 1.1 of hyperparameter choosing.
# train size: 83. test size: 42
# Performance of corresponding hyperparams: [32.85354323231778, 32.85354323231778, 32.85354323231778, 32.85354323231778, 33.54381645218506, 33.54381645218506, 33.54381645218506, 33.54381645218506, 33.841307304400594, 33.841307304400594, 33.841307304400594, 33.841307304400594, 33.858808343878614, 33.858808343878614, 33.858808343878614, 33.858808343878614, 33.86826051554247, 33.86826051554247, 33.86826051554247, 33.86826051554247]
# Round 1.2 of hyperparameter choosing.
# train size: 84. test size: 42
# Performance of corresponding hyperparams: [47.92562625383922, 47.92562625383922, 47.92562625383922, 47.92562625383922, 46.92218391242225, 46.92218391242225, 46.92218391242225, 46.92218391242225, 46.63825317236636, 46.63825317236636, 46.63825317236636, 46.63825317236636, 46.493859913399106, 46.493859913399106, 46.493859913399106, 46.493859913399106, 46.41361378595667, 46.41361378595667, 46.41361378595667, 46.41361378595667]
# Round 2.1 of hyperparameter choosing.
# train size: 83. test size: 42
# Performance of corresponding hyperparams: [35.1947590409755, 35.1947590409755, 35.1947590409755, 35.1947590409755, 35.568026801499364, 35.568026801499364, 35.568026801499364, 35.568026801499364, 35.58085726756315, 35.58085726756315, 35.58085726756315, 35.58085726756315, 35.58795630211861, 35.58795630211861, 35.58795630211861, 35.58795630211861, 35.5820467518023, 35.5820467518023, 35.5820467518023, 35.5820467518023]
# Round 2.2 of hyperparameter choosing.
# train size: 84. test size: 42
# Performance of corresponding hyperparams: